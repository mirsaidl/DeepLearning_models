# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import softmax_qn as snn

# %%
# Upload Mnist data
x = np.load('data/X.npy')
y = np.load('data/y.npy')
x.shape, y.shape
# Out:
# ((5000, 400), (5000, 1))

# %% [markdown]
# Every row is a number consisting 5000 numbers overall if you reshape row (20,20) you can see the number

# %%
# Show some of the numbers
m, n = x.shape

fig, axes = plt.subplots(10,10, figsize=(7,7))
fig.tight_layout(pad=0.13,rect=[0, 0.03, 1, 0.91]) #[left, bottom, right, top]

for i, ax in enumerate(axes.flat):
    # Select random
    random_idx = np.random.randint(m)
    # Reshape
    x_rand_rshaped = x[random_idx].reshape((20,20)).T
    
    # Display image
    ax.imshow(x_rand_rshaped, cmap='gray')
    
    # Display label
    ax.set_title(y[random_idx,0])
    ax.set_axis_off()
    fig.suptitle("Sample images", fontsize=20)

# %%
# Train/Test split
x_train, x_test, y_train, y_test = train_test_split(x,y, stratify=y, random_state=30)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3750, 400), (3750, 1), (1250, 400), (1250, 1))

# %%
# Normalize data
x_train_n = snn.normalize(x_train)
x_test_n = snn.normalize(x_test)
# One-hot encode
y_train_h = snn.one_hot_encode(y_train, 10)

# %%
# train the data
w1, b1, w2, b2 = snn.fit(x_train_n, y_train_h, hidden_units=64, learning_rate=0.01, epochs=1000)
# Out:
# (3750, 10) (3750, 10) (3750, 64)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 2
#       1 # train the data
# ----> 2 w1, b1, w2, b2 = snn.fit(x_train_n, y_train_h, hidden_units=64, learning_rate=0.01, epochs=1000)
#
# File ~\Desktop\DL\all\softmax_qn.py:101, in fit(x, y, hidden_units, learning_rate, epochs)
#      98     b2 -= learning_rate * db2
#     100     if i % math.ceil(epochs/10) == 0:
# --> 101         print(f"Iteration: {i} Loss: {sparse_crossentropy(a2, y)}")
#     103 return w1, b1, w2, b2
#
# File ~\Desktop\DL\all\softmax_qn.py:41, in sparse_crossentropy(y_pred, y)
#      39 # Convert y to integer type
#      40 y_int = y.astype(int)
# ---> 41 loss = -np.sum(np.log(y_pred[range(m), y_int])) / m
#      42 return loss
#
# IndexError: shape mismatch: indexing arrays could not be broadcast together with shapes (3750,) (3750,10)

# %%
y_train_h.shape
# Out:
# (3750, 10)
